# %% [markdown]
# # A simple example of U-Net network for PyTorch

# %%
import simulation as simulation
import numpy as np
import helper as helper
import matplotlib.pyplot as plt

# Generate some random images
input_images, target_masks = simulation.generate_random_data(192, 192, count=3)

for x in [input_images, target_masks]:
    print(x.shape)
    print(x.min(), x.max())

# change channel-order and make 3 channels for matplot
input_images_rgb = [x.astype(np.uint8) for x in input_images]

# map each channels (i.e. class) to each color
target_masks_rgb = [helper.masks_to_colorimg(x) for x in target_masks]

# left: input iamge, rigth: target mask (ground-truth)
helper.plot_side_by_side([input_images_rgb, target_masks_rgb])
# Out:
# (3, 192, 192, 3)
# 0 255
# (3, 6, 192, 192)
# 0.0 1.0

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

class SimDataset(Dataset):
    def __init__(self, count, transform=None):
        super().__init__()

        self.input_images, self.target_masks = simulation.generate_random_data(
            192, 192, count=count)
        self.transform = transform

    def __len__(self):
        return len(self.input_images)

    def __getitem__(self, index):
        image = self.input_images[index]
        mask = self.target_masks[index]

        if self.transform:
            image = self.transform(image)

        return [image, mask]

# use same transform for train/val for this example 
trans = transforms.Compose([
    transforms.ToTensor(),
])

train_set = SimDataset(2000, transform=trans)
val_set = SimDataset(200, transform=trans)

image_datasets = {
    'train': train_set, 'val': val_set
}

batch_size = 25

dataloaders = {
    'train': DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0),
    'val': DataLoader(val_set, batch_size=batch_size, shuffle=True, num_workers=0)
}

dataset_sizes = {
    x: len(image_datasets[x]) for x in image_datasets.keys()
}

dataset_sizes
# Out:
# {'train': 2000, 'val': 200}

# %%
def reverse_transform(inp):
    inp = inp.numpy().transpose((1,2,0))
    inp = np.clip(inp, 0, 1)
    inp = (inp * 255).astype(np.uint8)

    return inp

# get a batch of training data 
inputs, masks = next(iter(dataloaders['train']))

print(inputs.shape, masks.shape)
for x in [inputs.numpy(), masks.numpy()]:
    print(x.min(), x.max(), x.mean(), x.std())

plt.imshow(reverse_transform(inputs[0]))
# Out:
# torch.Size([25, 3, 192, 192]) torch.Size([25, 6, 192, 192])
# 0.0 1.0 0.023473307 0.15140118
# 0.0 1.0 0.0047676144 0.068883

# %%
import sys
sys.path.append('..')

from torchinfo import summary
import torch 
# from models.U_Net import UNet
from models.U_Net import UNet

unet = UNet(6).cuda()

summary(unet, input_size=(15, 3, 224, 224))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# UNet                                     --                        --
# ├─Sequential: 1-1                        [15, 64, 224, 224]        --
# │    └─Conv2d: 2-1                       [15, 64, 224, 224]        1,792
# │    └─ReLU: 2-2                         [15, 64, 224, 224]        --
# │    └─Conv2d: 2-3                       [15, 64, 224, 224]        36,928
# │    └─ReLU: 2-4                         [15, 64, 224, 224]        --
# ├─MaxPool2d: 1-2                         [15, 64, 112, 112]        --
# ├─Sequential: 1-3                        [15, 128, 112, 112]       --
# │    └─Conv2d: 2-5                       [15, 128, 112, 112]       73,856
# │    └─ReLU: 2-6                         [15, 128, 112, 112]       --
# │    └─Conv2d: 2-7                       [15, 128, 112, 112]       147,584
# │    └─ReLU: 2-8                         [15, 128, 112, 112]       --
# ├─MaxPool2d: 1-4                         [15, 128, 56, 56]         --
# ├─Sequential: 1-5                        [15, 256, 56, 56]         --
# │    └─Conv2d: 2-9                       [15, 256, 56, 56]         295,168
# │    └─ReLU: 2-10                        [15, 256, 56, 56]         --
# │    └─Conv2d: 2-11                      [15, 256, 56, 56]         590,080
# │    └─ReLU: 2-12                        [15, 256, 56, 56]         --
# ├─MaxPool2d: 1-6                         [15, 256, 28, 28]         --
# ├─Sequential: 1-7                        [15, 512, 28, 28]         --
# │    └─Conv2d: 2-13                      [15, 512, 28, 28]         1,180,160
# │    └─ReLU: 2-14                        [15, 512, 28, 28]         --
# │    └─Conv2d: 2-15                      [15, 512, 28, 28]         2,359,808
# │    └─ReLU: 2-16                        [15, 512, 28, 28]         --
# ├─Upsample: 1-8                          [15, 512, 56, 56]         --
# ├─Sequential: 1-9                        [15, 256, 56, 56]         --
# │    └─Conv2d: 2-17                      [15, 256, 56, 56]         1,769,728
# │    └─ReLU: 2-18                        [15, 256, 56, 56]         --
# │    └─Conv2d: 2-19                      [15, 256, 56, 56]         590,080
# │    └─ReLU: 2-20                        [15, 256, 56, 56]         --
# ├─Upsample: 1-10                         [15, 256, 112, 112]       --
# ├─Sequential: 1-11                       [15, 128, 112, 112]       --
# │    └─Conv2d: 2-21                      [15, 128, 112, 112]       442,496
# │    └─ReLU: 2-22                        [15, 128, 112, 112]       --
# │    └─Conv2d: 2-23                      [15, 128, 112, 112]       147,584
# │    └─ReLU: 2-24                        [15, 128, 112, 112]       --
# ├─Upsample: 1-12                         [15, 128, 224, 224]       --
# ├─Sequential: 1-13                       [15, 64, 224, 224]        --
# │    └─Conv2d: 2-25                      [15, 64, 224, 224]        110,656
# │    └─ReLU: 2-26                        [15, 64, 224, 224]        --
# │    └─Conv2d: 2-27                      [15, 64, 224, 224]        36,928
# │    └─ReLU: 2-28                        [15, 64, 224, 224]        --
# ├─Conv2d: 1-14                           [15, 6, 224, 224]         390
# ==========================================================================================
# Total params: 7,783,238
# Trainable params: 7,783,238
# Non-trainable params: 0
# Total mult-adds (G): 487.49
# ==========================================================================================
# Input size (MB): 9.03
# Forward/backward pass size (MB): 2829.93
# Params size (MB): 31.13
# Estimated Total Size (MB): 2870.09
# ==========================================================================================

# %%
from collections import defaultdict
import torch.nn.functional as F

def dice_loss(pred, target, smooth = 1.):
    pred = pred.contiguous()
    target = target.contiguous()    

    intersection = (pred * target).sum(dim=2).sum(dim=2)
    
    loss = (1 - ((2. * intersection + smooth) / (pred.sum(dim=2).sum(dim=2) + target.sum(dim=2).sum(dim=2) + smooth)))
    
    return loss.mean()

def calc_loss(pred, target, metrics, bce_weight=0.5):
    bce = F.binary_cross_entropy_with_logits(pred, target)

    pred = torch.sigmoid(pred)
    dice = dice_loss(pred, target)

    loss = bce * bce_weight + dice * (1 - bce_weight)

    metrics['bce'] += bce.data.cpu().numpy() * target.size(0)
    metrics['dice'] += dice.data.cpu().numpy() * target.size(0)
    metrics['loss'] += loss.data.cpu().numpy() * target.size(0)
    
    return loss

def print_metrics(metrics, epoch_samples, phase):
    outputs = []
    for k in metrics.keys():
        outputs.append("{}: {:4f}".format(k, metrics[k] / epoch_samples))

    print("{}: {}".format(phase, ",".join(outputs)))

# %%
import copy
import time
from utils.utils import *

def train_model(model, optimizer, scheduler, num_epochs=25):
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 1e10

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        since = time.time()

        # each epoch has a training and validation phase 
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                for param_group in optimizer.param_groups:
                    print('LR', param_group['lr'])

                model.train()
            else:
                model.eval()

            metrics = defaultdict(float)
            epoch_samples = 0

            for inputs, labels in dataloaders[phase]:
                inputs = tensor2var(inputs)
                labels = tensor2var(labels)

                # zero the parameter gradients 
                optimizer.zero_grad()

                # forward
                # track history if only in train 
                with torch.set_grad_enabled(phase=='train'):
                    outputs = model(inputs)
                    loss = calc_loss(outputs, labels, metrics)

                    # backward + optimize only if in training phase 
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics 
                epoch_samples += inputs.size(0)

            print_metrics(metrics, epoch_samples, phase)
            epoch_loss = metrics['loss'] / epoch_samples

            # deep copy the model 
            if phase == 'val' and epoch_loss < best_loss:
                print("saving best model")
                best_loss = epoch_loss
                best_model_wts = copy.deepcopy(model.state_dict())

        time_elapsed = time.time() - since 
        print('{:.0f}m {:0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val loss: {:4f}'.format(best_loss))

    # load best model weights 
    model.load_state_dict(best_model_wts)
    
    return model

# %%
import torch 
import torch.optim as optim
from torch.optim import lr_scheduler

num_class = 6

model = UNet(num_class).cuda()

# observe that all parameters are being optimzied 
optimizer_ft = optim.Adam(model.parameters(), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=25, gamma=0.1, verbose=True)

model = train_model(model, optimizer_ft, exp_lr_scheduler, num_epochs=40)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-04.
# Epoch 0/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# /opt/conda/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:129: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train: bce: 0.194300,dice: 0.991946,loss: 0.593123
# val: bce: 0.026664,dice: 0.944365,loss: 0.485515
# saving best model
# 0m 15.481282s
# Epoch 1/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.022753,dice: 0.794004,loss: 0.408379
# val: bce: 0.024848,dice: 0.656765,loss: 0.340806
# saving best model
# 0m 15.607921s
# Epoch 2/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.023794,dice: 0.544475,loss: 0.284134
# val: bce: 0.018395,dice: 0.432147,loss: 0.225271
# saving best model
# 0m 15.661165s
# Epoch 3/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.017359,dice: 0.409203,loss: 0.213281
# val: bce: 0.015205,dice: 0.375220,loss: 0.195212
# saving best model
# 0m 15.617154s
# Epoch 4/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.015081,dice: 0.353023,loss: 0.184052
# val: bce: 0.013238,dice: 0.317593,loss: 0.165415
# saving best model
# 0m 15.638598s
# Epoch 5/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.011692,dice: 0.261668,loss: 0.136680
# val: bce: 0.009597,dice: 0.209751,loss: 0.109674
# saving best model
# 0m 15.635006s
# Epoch 6/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.011349,dice: 0.236367,loss: 0.123858
# val: bce: 0.008341,dice: 0.200145,loss: 0.104243
# saving best model
# 0m 15.637705s
# Epoch 7/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.008529,dice: 0.186923,loss: 0.097726
# val: bce: 0.006164,dice: 0.177862,loss: 0.092013
# saving best model
# 0m 15.642377s
# Epoch 8/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.007610,dice: 0.164263,loss: 0.085936
# val: bce: 0.004987,dice: 0.118443,loss: 0.061715
# saving best model
# 0m 15.652015s
# Epoch 9/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.005330,dice: 0.100599,loss: 0.052965
# val: bce: 0.004936,dice: 0.082348,loss: 0.043642
# saving best model
# 0m 15.635042s
# Epoch 10/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.004982,dice: 0.081837,loss: 0.043410
# val: bce: 0.004490,dice: 0.077050,loss: 0.040770
# saving best model
# 0m 15.664352s
# Epoch 11/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.004589,dice: 0.071503,loss: 0.038046
# val: bce: 0.004084,dice: 0.065475,loss: 0.034780
# saving best model
# 0m 15.670909s
# Epoch 12/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.004654,dice: 0.082760,loss: 0.043707
# val: bce: 0.004050,dice: 0.065755,loss: 0.034903
# 0m 15.652419s
# Epoch 13/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.003867,dice: 0.061288,loss: 0.032577
# val: bce: 0.003608,dice: 0.056967,loss: 0.030288
# saving best model
# 0m 15.659557s
# Epoch 14/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.003565,dice: 0.056683,loss: 0.030124
# val: bce: 0.003631,dice: 0.054430,loss: 0.029031
# saving best model
# 0m 15.653630s
# Epoch 15/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.003284,dice: 0.052209,loss: 0.027746
# val: bce: 0.003232,dice: 0.050170,loss: 0.026701
# saving best model
# 0m 15.653961s
# Epoch 16/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.003103,dice: 0.049241,loss: 0.026172
# val: bce: 0.002945,dice: 0.048324,loss: 0.025635
# saving best model
# 0m 15.661051s
# Epoch 17/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.002959,dice: 0.047336,loss: 0.025147
# val: bce: 0.003045,dice: 0.053627,loss: 0.028336
# 0m 15.665308s
# Epoch 18/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.002835,dice: 0.046451,loss: 0.024643
# val: bce: 0.002888,dice: 0.045102,loss: 0.023995
# saving best model
# 0m 15.657177s
# Epoch 19/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.002608,dice: 0.042354,loss: 0.022481
# val: bce: 0.002876,dice: 0.043898,loss: 0.023387
# saving best model
# 0m 15.658453s
# Epoch 20/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.002472,dice: 0.040635,loss: 0.021553
# val: bce: 0.002652,dice: 0.045269,loss: 0.023961
# 0m 15.667606s
# Epoch 21/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.002384,dice: 0.039437,loss: 0.020911
# val: bce: 0.002493,dice: 0.041083,loss: 0.021788
# saving best model
# 0m 15.658692s
# Epoch 22/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.002345,dice: 0.039237,loss: 0.020791
# val: bce: 0.002390,dice: 0.039967,loss: 0.021178
# saving best model
# 0m 15.658068s
# Epoch 23/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-04.
# LR 0.0001
# train: bce: 0.002228,dice: 0.037102,loss: 0.019665
# val: bce: 0.002303,dice: 0.038782,loss: 0.020543
# saving best model
# 0m 15.663441s
# Epoch 24/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.002057,dice: 0.034218,loss: 0.018137
# val: bce: 0.002238,dice: 0.038330,loss: 0.020284
# saving best model
# 0m 15.709835s
# Epoch 25/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001988,dice: 0.033799,loss: 0.017893
# val: bce: 0.002224,dice: 0.037452,loss: 0.019838
# saving best model
# 0m 15.657045s
# Epoch 26/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001986,dice: 0.033568,loss: 0.017777
# val: bce: 0.002221,dice: 0.037762,loss: 0.019991
# 0m 15.646415s
# Epoch 27/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001971,dice: 0.033406,loss: 0.017689
# val: bce: 0.002186,dice: 0.037576,loss: 0.019881
# 0m 15.646842s
# Epoch 28/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001951,dice: 0.033172,loss: 0.017562
# val: bce: 0.002195,dice: 0.038012,loss: 0.020103
# 0m 15.652374s
# Epoch 29/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001941,dice: 0.033133,loss: 0.017537
# val: bce: 0.002188,dice: 0.036898,loss: 0.019543
# saving best model
# 0m 15.662598s
# Epoch 30/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001930,dice: 0.032872,loss: 0.017401
# val: bce: 0.002198,dice: 0.036891,loss: 0.019544
# 0m 15.658354s
# Epoch 31/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001923,dice: 0.032739,loss: 0.017331
# val: bce: 0.002190,dice: 0.037465,loss: 0.019827
# 0m 15.660117s
# Epoch 32/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001906,dice: 0.032594,loss: 0.017250
# val: bce: 0.002145,dice: 0.037276,loss: 0.019710
# 0m 15.662222s
# Epoch 33/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001905,dice: 0.032535,loss: 0.017220
# val: bce: 0.002144,dice: 0.036702,loss: 0.019423
# saving best model
# 0m 15.665230s
# Epoch 34/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001890,dice: 0.032317,loss: 0.017103
# val: bce: 0.002132,dice: 0.036612,loss: 0.019372
# saving best model
# 0m 15.662474s
# Epoch 35/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001880,dice: 0.032094,loss: 0.016987
# val: bce: 0.002119,dice: 0.036143,loss: 0.019131
# saving best model
# 0m 15.667225s
# Epoch 36/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001861,dice: 0.031934,loss: 0.016898
# val: bce: 0.002105,dice: 0.036205,loss: 0.019155
# 0m 15.668371s
# Epoch 37/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001842,dice: 0.031767,loss: 0.016804
# val: bce: 0.002129,dice: 0.036166,loss: 0.019147
# 0m 15.651671s
# Epoch 38/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001833,dice: 0.031575,loss: 0.016704
# val: bce: 0.002122,dice: 0.035984,loss: 0.019053
# saving best model
# 0m 15.656734s
# Epoch 39/39
# ----------
# Adjusting learning rate of group 0 to 1.0000e-05.
# LR 1e-05
# train: bce: 0.001829,dice: 0.031407,loss: 0.016618
# val: bce: 0.002058,dice: 0.035919,loss: 0.018989
# saving best model
# 0m 15.702493s
# Best val loss: 0.018989

# %%
# prediction 

model.eval() # set model to evaluate mode 

test_dataset = SimDataset(3, transform=trans)
test_loader = DataLoader(test_dataset, batch_size=3, shuffle=False, num_workers=0)

inputs, labels = next(iter(test_loader))
inputs = tensor2var(inputs)
labels = tensor2var(labels)

pred = model(inputs)
print(pred.shape)

# change channel-order and make 3 channels for matplot 
input_images_rgb = [reverse_transform(x) for x in inputs.cpu()]

# Map each channel (i.e. class) to each color 
target_masks_rgb = [helper.masks_to_colorimg(x) for x in labels.cpu()]
pred_rgb = [helper.masks_to_colorimg(x) for x in pred.cpu()]

helper.plot_side_by_side([input_images_rgb, target_masks_rgb, pred_rgb])
# Out:
# torch.Size([3, 6, 192, 192])
